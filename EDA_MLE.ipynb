# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
data = 'machine_learning_engineers.csv'
data = pd.read_csv(data)
data.head()
# Remove row 0
data = data.iloc[1:]

# %%
df = pd.DataFrame(data)

# %%
from processing_function import *

# %%
fhelp("vvc")
fhelp("cavo")
fhelp("gcbp")
# Out:
# vvc(dataframe, column_name, xlabel, ylabel, title):
#   - Hiển thị số lần xuất hiện của từng giá trị duy nhất trong cột được chỉ định bằng biểu đồ cột.
#   Ví dụ:
#     df = pd.DataFrame(data)
#     column_name = 'Q5'
#     vvc(df, column_name, 'Categories', 'Counts', 'Category Count')
# cavo(dataframe, column_names):
#   - Đếm số lượng '1' trong các cột được chỉ định và hiển thị biểu đồ cột.
#   Ví dụ:
#     df = pd.DataFrame(data)
#     counts = cavo(df, ['Q7_Part1', 'Q7_Part2', 'Q7_Part3'])
#     print(counts)
# gcbp(dataframe, selected_cols, prefix):
#   - Lấy tất cả các tên cột bắt đầu bằng tiền tố được chỉ định.
#   Ví dụ:
#     df = pd.DataFrame(data)
#     cols = gcbp(df, 'Q7_Part1', 'Q7')
#     print(cols)

# %% [markdown]
# #Học vấn

# %%
df = pd.DataFrame(data)
column_x = "Q4"
column_y = "Q5"
title = "Study level in relation to the working field"
vvc(df, "Q4", "xlabel", "ylabel", title)

# %% [markdown]
# #Công cụ

# %%
df = pd.DataFrame(data)
cavo(df, gcbp(df, "Q7"))
title = "Study level in relation to the working field"
vvc(df, "Q7", "xlabel", "ylabel", title)
# Out:
# Column 'Q7' not found in the dataframe.

# %% [markdown]
# #Học cái gì

# %%
cavo(df, gcbp(df, "Q16",))
cavo(df, gcbp(df, "Q17",))
# Out:
# /workspaces/story-telling/processing_function.py:272: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# {'Q17_Linear or Logistic Regression': np.int64(673),
#  'Q17_Decision Trees or Random Forests': np.int64(554),
#  'Q17_Gradient Boosting Machines (xgboost, lightgbm, etc)': np.int64(403),
#  'Q17_Bayesian Approaches': np.int64(249),
#  'Q17_Evolutionary Approaches': np.int64(72),
#  'Q17_Dense Neural Networks (MLPs, etc)': np.int64(406),
#  'Q17_Convolutional Neural Networks': np.int64(648),
#  'Q17_Generative Adversarial Networks': np.int64(140),
#  'Q17_Recurrent Neural Networks': np.int64(404),
#  'Q17_Transformer Networks (BERT, gpt-3, etc)': np.int64(208),
#  'Q17_Part_11': np.int64(0),
#  'Q17_Other': np.int64(26),
#  'Q17Total': np.int64(3783)}

# %%
cavo(df, gcbp(df, "Q23"))
# Out:
# {'Q23_Analyze and understand data to influence product or business decisions': np.int64(448),
#  'Q23_Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data': np.int64(347),
#  'Q23_Build prototypes to explore applying machine learning to new areas': np.int64(502),
#  'Q23_Build and/or run a machine learning service that operationally improves my product or workflows': np.int64(442),
#  'Q23_Experimentation and iteration to improve existing ML models': np.int64(463),
#  'Q23_Do research that advances the state of the art of machine learning': np.int64(334),
#  'Q23_None of these activities are an important part of my role at work': np.int64(50),
#  'Q23_Other': np.int64(51),
#  'Q23Total': np.int64(2637)}

# %%
cavo(df, gcbp(df, "Q33_A"))
cavo(df, gcbp(df, "Q34_A"))
cavo(df, gcbp(df, "Q35_A"))
cavo(df, gcbp(df, "Q36"))
# Out:
# {'Q36_ Plotly Dash ': np.int64(23),
#  'Q36_ Streamlit ': np.int64(32),
#  'Q36_ NBViewer ': np.int64(11),
#  'Q36_ GitHub ': np.int64(381),
#  'Q36_ Personal blog ': np.int64(71),
#  'Q36_ Kaggle ': np.int64(214),
#  'Q36_ Colab ': np.int64(172),
#  'Q36_ Shiny ': np.int64(7),
#  'Q36_I do not share my work publicly': np.int64(164),
#  'Q36_Other': np.int64(24),
#  'Q36Total': np.int64(1099)}

# %%
df = pd.DataFrame(data)
vvc(df, "Q15", "xlabel", "ylabel", title)

# %%
df = pd.DataFrame(data)
vvc(df, "Q11", "xlabel", "ylabel", title)

# %%
cavo(df, gcbp(df, "Q26_A",))
cavo(df, gcbp(df, "Q27_A",))
cavo(df, gcbp(df, "Q28_A",))
# Out:
# /workspaces/story-telling/processing_function.py:272: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# {'Q28_A_ Amazon SageMaker ': np.int64(99),
#  'Q28_A_ Amazon Forecast ': np.int64(29),
#  'Q28_A_ Amazon Rekognition ': np.int64(42),
#  'Q28_A_ Azure Machine Learning Studio ': np.int64(56),
#  'Q28_A_ Azure Cognitive Services ': np.int64(45),
#  'Q28_A_ Google Cloud AI Platform / Google Cloud ML Engine': np.int64(105),
#  'Q28_A_ Google Cloud Video AI ': np.int64(37),
#  'Q28_A_ Google Cloud Natural Language ': np.int64(56),
#  'Q28_A_ Google Cloud Vision AI ': np.int64(74),
#  'Q28_A_No / None': np.int64(229),
#  'Q28_A_Other': np.int64(13),
#  'Q28_ATotal': np.int64(785)}

# %% [markdown]
# #Chi phí đầu tư

# %%
vvc(df, "Q25", "xlabel", "ylabel", title)

# %% [markdown]
# #Phân bổ trong công ty

# %%
vvc(df, "Q20", "xlabel", "ylabel", title)

# %%
vvc(df, 'Q3', 'x', 'y', 'title', bar_width= 4, bar_spacing= 8,angling=90,label_size=8)

# %%
vvc(df, 'Q3', 'x', 'y', 'title', bar_width= 4, bar_spacing= 8,angling=90,label_size=8)

# %%
# Đếm số lượng từng mức lương
salary_counts = vietnam_salary['Q25'].value_counts()

# Vẽ biểu đồ cột
fig, ax = plt.subplots(figsize=(10, 6))
salary_counts.plot(kind='bar', ax=ax, color='skyblue', edgecolor='black')

# Thêm tiêu đề và nhãn
ax.set_title('Phân phối mức lương tại Việt Nam', fontsize=14)
ax.set_xlabel('Mức lương ($USD)', fontsize=12)
ax.set_ylabel('Số lượng', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Đếm số lượng từng mức lương
# ----> 2 salary_counts = vietnam_salary['Q25'].value_counts()
#       4 # Vẽ biểu đồ cột
#       5 fig, ax = plt.subplots(figsize=(10, 6))
#
# NameError: name 'vietnam_salary' is not defined

# %%
vvc(df, "Q25", "Mức lương ($USD)", "Số lượng", "Phân phối mức lương toàn cầu")

# %%
print("abc")
# Out:
# abc
