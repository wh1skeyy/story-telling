# %%
import pandas as pd
data = 'cleaned-data.csv'
data = pd.read_csv(data)
data.head()
# Remove row 0
data = data.iloc[1:]
# Out:
# /tmp/ipykernel_3054/3089168145.py:3: DtypeWarning: Columns (183,206) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data)

# %%
from processing_function import *

# %%
# Example usage of the vh function
df = pd.DataFrame(data)
column_x = "Q4"
column_y = "Q5"
title = "Study level in relation to the working field"
heatmapping(df, column_x, column_y, title)

# %%
cavo(df, ['Q7_Part_1', 'Q7_Part_2'])
# Out:
# {'Q7_Part_1': np.int64(15529), 'Q7_Part_2': np.int64(4276)}

# %%
vvc(df, 'Q1', 'x', 'y', 'title')

# %%
vvc(df, 'Q3', 'x', 'y', 'title')

# %%
vvc(df, 'Q4', 'x', 'y', 'title')

# %%
vvc(df, 'Q6', 'x', 'y', 'title')

# %%
vvc(df, 'Q20', 'x', 'y', 'title')

# %%
vvc(df, 'Q24', 'x', 'y', 'title')
