# %%
import pandas as pd
data = 'cleaned-data.csv'
data = pd.read_csv(data)
data.head()
# Remove row 0
data = data.iloc[1:]
# Out:
# /tmp/ipykernel_39632/3089168145.py:3: DtypeWarning: Columns (183,206) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data)

# %%
from processing_function import *

# %%
# Example usage of the vh function
df = pd.DataFrame(data)
column_x = "Q4"
column_y = "Q5"
title = "Study level in relation to the working field"
heatmapping(df, column_x, column_y, title)
