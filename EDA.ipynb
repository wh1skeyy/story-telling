# %%
import pandas as pd
data = 'cleaned-data.csv'
data = pd.read_csv(data)
data.head()
# Remove row 0
data = data.iloc[1:]

# %%
from processing_function import *

# %%
# Example usage of the vh function
df = pd.DataFrame(data)
column_x = "Q4"
column_y = "Q5"
title = "Study level in relation to the working field"
heatmapping(df, column_x, column_y, title)

# %%
cavo(df, gcbp(df, "Q7"))
# Out:
# {'Q7_Python': np.int64(15529),
#  'Q7_R': np.int64(4276),
#  'Q7_SQL': np.int64(7534),
#  'Q7_C': np.int64(3314),
#  'Q7_C++': np.int64(3827),
#  'Q7_Java': np.int64(3367),
#  'Q7_Javascript': np.int64(2994),
#  'Q7_Julia': np.int64(262),
#  'Q7_Swift': np.int64(198),
#  'Q7_Bash': np.int64(1776),
#  'Q7_MATLAB': np.int64(2216),
#  'Q7_Part_12': np.int64(0),
#  'Q7_Other': np.int64(1944)}

# %%
vvc(df, 'Q1', 'x', 'y', 'title')

# %%
# Create a mapping of old values to new shorter values for Q3
short_names_q3 = {
    'United States of America': 'USA',
    'United Kingdom of Great Britain and Northern Ireland': 'UK',
    'Some other long country name': 'Shortened Name'  # Add more mappings as needed
}
# Replace the values in the Q3 column
df['Q3'] = df['Q3'].replace(short_names_q3)

vvc(df, 'Q3', 'x', 'y', 'title', bar_width= 4, bar_spacing= 8,angling=90,label_size=8)

# %%
# Create a mapping of old values to new shorter values
short_names = {
    'Master’s degree': 'Master',
    'Bachelor’s degree': 'Bachelor',
    'Doctoral degree': 'Doctorate',
    'Some college/university study without earning a bachelor’s degree': 'Some College',
    'Professional degree': 'Professional',
    'I prefer not to answer': 'No Answer',
    'No formal education past high school': 'High School'
}

# Replace the values in the Q4 column
df['Q4'] = df['Q4'].replace(short_names)
vvc(df, 'Q4', 'x', 'y', 'title')

# %%
df['Q6'] = df['Q6'].replace({'I have never written code': 'Never'})
vvc(df, 'Q6', 'x', 'y', 'title')
# Generate a pie chart for Q6
df['Q6'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(8, 8), title='Distribution of Q6')
# Out:
# <Axes: title={'center': 'Distribution of Q6'}, ylabel='count'>

# %%
vvc(df, 'Q20', 'x', 'y', 'title')

# %%
vvc(df, 'Q24', 'x', 'y', 'title',label_size=8)

# %%
heatmapping(df, gcbp(df, 'Q16'), gcbp(df, 'Q17'), 'Tự đặt tên cho biểu đồ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 heatmapping(df, gcbp(df, 'Q16'), gcbp(df, 'Q17'), 'Tự đặt tên cho biểu đồ')
#
# File /workspaces/story-telling/processing_function.py:392, in heatmapping(dataframe, column_x, column_y, title)
#     372 def heatmapping(dataframe, column_x, column_y, title):
#     373     """
#     374     Creates a heatmap based on the counts of unique value pairs in two selected columns.
#     375     Parameters:
#    (...)    390     - None
#     391     """
# --> 392     if column_x in dataframe.columns and column_y in dataframe.columns:
#     393         heatmap_data = pd.crosstab(dataframe[column_y], dataframe[column_x])
#     394         plt.figure(figsize=(10, 8))
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:5358, in Index.__contains__(self, key)
#    5323 def __contains__(self, key: Any) -> bool:
#    5324     """
#    5325     Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)   5356     False
#    5357     """
# -> 5358     hash(key)
#    5359     try:
#    5360         return key in self._engine
#
# TypeError: unhashable type: 'list'
